# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams["figure.figsize"] = (12, 9)

# %%
ppatch_metric_pdf = pd.read_csv("ppatch_metric_utf8.csv")

# %%
ppatch_metric_pdf.columns
# Out:
# Index(['Name and Cultivars or Varieties (sorted by name)', '$/kg', 'kg/m3',
#        '$/m3'],
#       dtype='object')

# %%
plt.scatter(ppatch_metric_pdf["kg/m3"], ppatch_metric_pdf["$/kg"])

# %%
ppatch_metric_pdf
# Out:
#      Name and Cultivars or Varieties (sorted by name)        $/kg      kg/m3  \
# 0   Spinach, Spring/Fall {Spinacia oleracea}: (1) ...    5.298013   0.341295
# 1                Cabbage {Brassica oleracea}: 'Pixie'    2.649007   2.291550
# 2   Broccoli, Chinese {Brassica oleracea, Alboglab...    5.298013   1.560204
# 3          Broccoli {Brassica oleracea ...}: 'Umpqua'    4.392936   1.901499
# 4   Kohlrabi {Brassica oleracea, Gongylodes group}...    3.973510   2.437819
# 5            Parsley {Petroselinum crispum}: 'Krausa'    7.773852   1.254923
# 6   Squash, Winter, Acorn {Cucurbita pepo}: (1) 'T...    4.392936   2.681601
# 7   Squash, Winter, Hubbard {Cucurbita maxima Hubb...    5.298013   2.779114
# 8   Rutabaga {Brassica napus or napobrassica}: 'Ma...    6.600442   2.242794
# 9     Greens, Mustard {Brassica juncea}: 'Green Wave'    6.512141   2.291550
# 10     Cabbage, Savoy {Brassica oleracea}: 'Ormskirk'    4.392936   3.900511
# ...
